# %% [markdown]
# <a href="https://colab.research.google.com/github/mateuszrajca69/r/blob/main/poprawa_Rajca_Mateusz_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym 
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(4, 3))

from IPython import display
display.clear_output(wait=True)

# %%
env = gym.make("Taxi-v3").env
env.reset()
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
env.action_space
# Out:
# Discrete(6)

# %%
env.observation_space
# Out:
# Discrete(500)

# %%
env.P
env.P[199]
# Out:
# {0: [(1.0, 299, -1, False)],
#  1: [(1.0, 99, -1, False)],
#  2: [(1.0, 199, -1, False)],
#  3: [(1.0, 179, -1, False)],
#  4: [(1.0, 199, -10, False)],
#  5: [(1.0, 199, -10, False)]}

# %%
env.step(2)
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)

# %%
for t in range(200):
  action = env.action_space.sample()
  observation, reward, done, info = env.step(action)
  print(t, observation, reward, done)
# Out:
# 0 87 -1 False
# 1 87 -1 False
# 2 87 -10 False
# 3 187 -1 False
# 4 287 -1 False
# 5 267 -1 False
# 6 367 -1 False
# 7 367 -1 False
# 8 387 -1 False
# 9 387 -10 False
# 10 487 -1 False
# 11 387 -1 False
# 12 487 -1 False
# 13 487 -1 False
# 14 467 -1 False
# 15 487 -1 False
# 16 487 -1 False
# 17 487 -1 False
# 18 487 -1 False
# 19 487 -1 False
# 20 487 -1 False
# 21 467 -1 False
# 22 487 -1 False
# 23 387 -1 False
# 24 387 -1 False
# 25 287 -1 False
# 26 287 -10 False
# 27 187 -1 False
# 28 167 -1 False
# 29 267 -1 False
# 30 267 -10 False
# 31 167 -1 False
# 32 187 -1 False
# 33 87 -1 False
# 34 87 -1 False
# 35 87 -1 False
# 36 99 -1 False
# 37 79 -1 False
# 38 79 -1 False
# 39 79 -10 False
# 40 79 -10 False
# 41 79 -10 False
# 42 79 -1 False
# 43 179 -1 False
# 44 179 -10 False
# 45 199 -1 False
# 46 199 -10 False
# 47 99 -1 False
# 48 199 -1 False
# 49 199 -1 False
# 50 179 -1 False
# 51 279 -1 False
# 52 259 -1 False
# 53 239 -1 False
# 54 219 -1 False
# 55 319 -1 False
# ...

# %%
for t in range(199):
  action = env.action_space.sample()
  observation, reward, done, info = env.step(action)
  env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# ...
